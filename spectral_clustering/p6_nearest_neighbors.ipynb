# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
import matplotlib as mpl
import random
import numpy as np
import pandas as pd
from sklearn.manifold import SpectralEmbedding
import math
import networkx as nx
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from scipy import linalg

# %%
# random color generation
random.seed(0)
colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(20)]

colors_name = []
for l in y:
    colors_name.append(colors[l])
colors_name[:5]
# Out:
# ['#CD18FC', '#9FB649', '#CD18FC', '#9FB649', '#9FB649']

# %%
k = 2
c_std = []
np.random.seed(3)
for i in range(k):
    c_std.append(np.random.rand())
x, y = make_blobs(n_samples=100, centers=k, n_features=2, cluster_std=c_std,
                  random_state=42)
print(x[:5]) # coordinates
print(y[:5]) # class labels

colors_name = []
for l in y:
    colors_name.append(colors[l])
colors_name[:5]  

plt.figure(figsize=(5,2))
plt.hist(y, bins=np.arange(0,6,0.5), edgecolor='white')
plt.title('Class distribution')
plt.show()

df = pd.DataFrame(x)
plt.scatter(df[0], df[1], color=colors_name)
plt.title(f'{k} clusters')
plt.show()

se = SpectralEmbedding(n_components=1, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)

# Plot the embedded data
plt.scatter(range(len(x_se[:, 0])), x_se[:, 0], c=colors_name, )
plt.title('one component')
plt.show()

se = SpectralEmbedding(n_components=2, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)

# Plot the embedded data
plt.scatter(x_se[:, 0], x_se[:, 1], c=colors_name, )
plt.title('two components')
plt.show()
# Out:
# [[-2.77312579  8.91202555]
#  [ 5.40683922  2.71941731]
#  [-2.80904249  9.07538206]
#  [ 5.22201895  3.3163795 ]
#  [ 4.80095409  2.89881998]]
# [0 1 0 1 1]

# %%
k = 3
c_std = []
np.random.seed(3)
for i in range(k):
    c_std.append(np.random.rand())
x, y = make_blobs(n_samples=100, centers=k, n_features=2, cluster_std=c_std, random_state=42)
print(x[:5]) # coordinates
print(y[:5]) # class labels

colors_name = []
for l in y:
    colors_name.append(colors[l])
colors_name[:5]  

plt.figure(figsize=(5,2))
plt.hist(y, bins=np.arange(0,6,0.5), edgecolor='white')
plt.title('Class distribution')
plt.show()

df = pd.DataFrame(x)
plt.scatter(df[0], df[1], color=colors_name)
plt.title(f'{k} clusters')
plt.show()

###
se = SpectralEmbedding(n_components=1, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(range(len(x_se[:, 0])), x_se[:, 0], c=colors_name, )
plt.title('one component')
plt.show()

se = SpectralEmbedding(n_components=2, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(x_se[:, 0], x_se[:, 1], c=colors_name, )
plt.title('two components')
plt.show()

se = SpectralEmbedding(n_components=3, n_neighbors=99)
x_se = se.fit_transform(x)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_se[:, 0], x_se[:, 1], x_se[:, 2], c=colors_name, )
plt.show()
# Out:
# [[-7.1259635  -7.32078583]
#  [ 5.21596928  1.1015358 ]
#  [-2.76778313  9.31312706]
#  [ 5.63326457  0.98045191]
#  [-6.77554515 -6.71697472]]
# [2 1 0 1 2]

# %%
k = 4
c_std = []
np.random.seed(3)
for i in range(k):
    c_std.append(np.random.rand())
x, y = make_blobs(n_samples=100, centers=k, n_features=2, cluster_std=c_std, random_state=42)
print(x[:5]) # coordinates
print(y[:5]) # class labels

colors_name = []
for l in y:
    colors_name.append(colors[l])
colors_name[:5]  

plt.figure(figsize=(5,2))
plt.hist(y, bins=np.arange(0,6,0.5), edgecolor='white')
plt.title('Class distribution')
plt.show()

df = pd.DataFrame(x)
plt.scatter(df[0], df[1], color=colors_name)
plt.title(f'{k} clusters')
plt.show()

###
se = SpectralEmbedding(n_components=1, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(range(len(x_se[:, 0])), x_se[:, 0], c=colors_name, )
plt.title('one component')
plt.show()

se = SpectralEmbedding(n_components=2, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(x_se[:, 0], x_se[:, 1], c=colors_name, )
plt.title('two components')
plt.show()

se = SpectralEmbedding(n_components=3, n_neighbors=99)
x_se = se.fit_transform(x)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_se[:, 0], x_se[:, 1], x_se[:, 2], c=colors_name, )
plt.show()
# Out:
# [[-9.27089336  6.54969714]
#  [-6.64297118 -7.23817386]
#  [-2.76778313  9.31312706]
#  [-6.47154768 -7.28791471]
#  [-8.6555601   7.60998713]]
# [3 2 0 2 3]

# %%
k = 5
c_std = []
np.random.seed(5)
for i in range(k):
    c_std.append(np.random.rand())
x, y = make_blobs(n_samples=100, centers=k, n_features=2, cluster_std=c_std, random_state=42)
print(x[:5]) # coordinates
print(y[:5]) # class labels

colors_name = []
for l in y:
    colors_name.append(colors[l])
colors_name[:5]  

plt.figure(figsize=(5,2))
plt.hist(y, bins=np.arange(0,6,0.5), edgecolor='white')
plt.title('Class distribution')
plt.show()

df = pd.DataFrame(x)
plt.scatter(df[0], df[1], color=colors_name)
plt.title(f'{k} clusters')
plt.show()

###
se = SpectralEmbedding(n_components=1, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(range(len(x_se[:, 0])), x_se[:, 0], c=colors_name, )
plt.title('one component')
plt.show()

se = SpectralEmbedding(n_components=2, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(x_se[:, 0], x_se[:, 1], c=colors_name, )
plt.title('two components')
plt.show()

se = SpectralEmbedding(n_components=3, n_neighbors=99)
x_se = se.fit_transform(x)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_se[:, 0], x_se[:, 1], x_se[:, 2], c=colors_name, )
plt.show()
# Out:
# [[-6.75831259 -6.42730046]
#  [ 2.0286505   4.87137386]
#  [-2.61207319  8.9108973 ]
#  [ 1.3494311   3.70340731]
#  [-8.74678693  6.86102469]]
# [2 4 0 4 3]

# %%
k = 6
c_std = []
np.random.seed(k)
for i in range(k):
    c_std.append(np.random.rand())
x, y = make_blobs(n_samples=100, centers=k, n_features=2, cluster_std=c_std, random_state=42)
print(x[:5]) # coordinates
print(y[:5]) # class labels

colors_name = []
for l in y:
    colors_name.append(colors[l])
colors_name[:5]  

plt.figure(figsize=(5,2))
plt.hist(y, bins=np.arange(0,6,0.5), edgecolor='white')
plt.title('Class distribution')
plt.show()

df = pd.DataFrame(x)
plt.scatter(df[0], df[1], color=colors_name)
plt.title(f'{k} clusters')
plt.show()

###
se = SpectralEmbedding(n_components=1, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(range(len(x_se[:, 0])), x_se[:, 0], c=colors_name, )
plt.title('one component')
plt.show()

se = SpectralEmbedding(n_components=2, n_neighbors=99) # affinity = nearest_neighbors (default)
x_se = se.fit_transform(x)
# Plot the embedded data
plt.scatter(x_se[:, 0], x_se[:, 1], c=colors_name, )
plt.title('two components')
plt.show()

se = SpectralEmbedding(n_components=3, n_neighbors=99)
x_se = se.fit_transform(x)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_se[:, 0], x_se[:, 1], x_se[:, 2], c=colors_name, )
plt.show()
# Out:
# [[ -8.8138578    7.41485752]
#  [ -9.58057331  10.2631255 ]
#  [ -2.92296481   8.59845459]
#  [-10.40809512   8.84014232]
#  [ -8.83417263   7.30252968]]
# [3 5 0 5 3]
