# %%
from sklearn import datasets
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
from my_le_21 import My_LE
if __name__=="__main__":
    data = My_LE()

# %%
random.seed(42)
rand_num = random.sample(range(0, 101), 25)

def get_blobs(n_samples=200, centers=4, random_state=42):
    X, Y = datasets.make_blobs(n_samples=n_samples, centers=centers, random_state=random_state)
    return X, Y

# visualization of original datasets
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten() 
for i in range(25):
    seed = rand_num[i]
    X, Y = get_blobs(random_state=seed)
    ax = axes[i]
    ax.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis', s=30, alpha=0.8)
    ax.set_title(f'random state:{seed}')
    ax.set_xticks([])
    ax.set_yticks([])
plt.suptitle('Original data:blobs', fontsize=25)
plt.tight_layout()
plt.show()

# %%
# visualization of original datasets
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten() 
for i in range(25):
    seed = rand_num[i]
    X, Y = get_blobs(random_state=seed)
    data.get_data(X, n_centers=4)
    data.get_label(Y)
    data.embed_data()
    best_pair = data.pair
    ax = axes[i]
    ax.scatter(data.def_vec[best_pair[0]], data.def_vec[best_pair[1]], c=Y, cmap='viridis', s=30, alpha=0.8)
    ax.set_title(f'random state:{seed}')
    ax.set_xticks([])
    ax.set_yticks([])
plt.suptitle('Data embedded on LE:blobs', fontsize=25)
plt.tight_layout()
plt.show()

# %%
print(f'average score : ', np.round(sum(data.score_list) / len(data.score_list),3))
# Out:
# average score :  0.924

# %%
def get_circles(n_samples=200, centers=4, random_state=42):
    n = random.randint(0, n_samples)
    X, Y = datasets.make_circles(n_samples=n_samples, factor=rand_factor[n], noise=rand_noise[n], random_state=random_state)
    return X, Y

rand_factor = []
rand_noise = []
for i in range(200):
    rand_factor.append(random.random())
    rand_noise.append(random.random()*0.1)
    
# visualization of original datasets
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten() 
for i in range(25):
    seed = rand_num[i]
    X, Y = get_circles(random_state=seed)
    ax = axes[i]
    ax.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis', s=30, alpha=0.8)
    ax.set_title(f'random state:{seed}')
    ax.set_xticks([])
    ax.set_yticks([])
plt.suptitle('Original data:circles', fontsize=25)
plt.tight_layout()
plt.show()

# %%
# visualization of original datasets
data.score_list = [] 
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten() 
for i in range(25):
    seed = rand_num[i]
    X, Y = get_circles(random_state=seed)
    data.get_data(X, n_centers=2)
    data.get_label(Y)
    data.embed_data()
    best_pair = data.pair
    ax = axes[i]
    ax.scatter(data.def_vec[best_pair[0]], data.def_vec[best_pair[1]], c=Y, cmap='viridis', s=30, alpha=0.8)
    ax.set_title(f'random state:{seed}')
    ax.set_xticks([])
    ax.set_yticks([])
plt.suptitle('Data embedded on LE:circles', fontsize=25)
plt.tight_layout()
plt.show()

# %%
print(f'average score : ', np.round(sum(data.score_list) / len(data.score_list),3))
# Out:
# average score :  0.635

# %%
def get_moons(n_samples=200, centers=4, random_state=42):
    n = random.randint(0, n_samples)
    X, Y = datasets.make_moons(n_samples=n_samples, noise=rand_noise[n], random_state=random_state)
    return X, Y
   
# visualization of original datasets
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten() 
for i in range(25):
    seed = rand_num[i]
    X, Y = get_moons(random_state=seed)
    ax = axes[i]
    ax.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis', s=30, alpha=0.8)
    ax.set_title(f'random state:{seed}')
    ax.set_xticks([])
    ax.set_yticks([])
plt.suptitle('Original data:moons', fontsize=25)
plt.tight_layout()
plt.show()

# %%
# visualization of original datasets
data.score_list = [] 
fig, axes = plt.subplots(5, 5, figsize=(15, 15))
axes = axes.flatten() 
for i in range(25):
    seed = rand_num[i]
    X, Y = get_circles(random_state=seed)
    data.get_data(X, n_centers=2)
    data.get_label(Y)
    data.embed_data()
    best_pair = data.pair
    ax = axes[i]
    ax.scatter(data.def_vec[best_pair[0]], data.def_vec[best_pair[1]], c=Y, cmap='viridis', s=30, alpha=0.8)
    ax.set_title(f'random state:{seed}')
    ax.set_xticks([])
    ax.set_yticks([])
plt.suptitle('Data embedded on LE:moons', fontsize=25)
plt.tight_layout()
plt.show()

# %%
print(f'average score : ', np.round(sum(data.score_list) / len(data.score_list),3))
# Out:
# average score :  0.646
