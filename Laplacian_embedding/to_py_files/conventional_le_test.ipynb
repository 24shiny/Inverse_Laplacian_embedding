# %%
from conventional_le_5 import Conventional_LE
from sklearn import datasets
import matplotlib.pyplot as plt

# %%
X, _ = datasets.make_blobs(n_samples=256, centers=4, random_state=42)
plt.scatter(X[:, 0], X[:, 1], c=_, cmap='viridis', s=30, alpha=0.8)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

data = Conventional_LE(X=X, n_centers=4)
data.embed_data()
# Out:
# 0.7893791763875907
