# %%
from my_quantum_le_32 import My_quantum_LE

if __name__=="__main__":
    data = My_quantum_LE()
# Out:
# program stops at 1th iteration
# program stops at 1th iteration
# program stops at 3th iteration
# program stops at 5th iteration

# %%
from sklearn import datasets
X, Y = datasets.make_circles(n_samples=16, factor=0.4, noise=0.05, random_state=42)
data.get_data(X, n_centers=2)
data.get_label(Y)
data.plot_example_data()
data.embed_data()
